# %%
import pandas as pd 
data = pd.read_excel("my_test.xlsx")
data.head() # the start and end positions are 2 and 5
# Out:
#    Answer  K_Value
# 0       1        3
# 1       5        5
# 2      21        7
# 3      84        9
# 4     330       11

# %%
data.shape
# Out:
# (4999, 2)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(data.Answer, marker='o')
plt.title('Line Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
imp
